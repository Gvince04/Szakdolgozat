# %%
import wfdb
import numpy as np

test_file_path = "../../data/records500/00000/00001_hr" 

signal, meta = wfdb.rdsamp(test_file_path)

print("A beolvasott adat típusa:", type(signal))
print("Az adat alakja (shape):", signal.shape)
# Out:
# A beolvasott adat típusa: <class 'numpy.ndarray'>
# Az adat alakja (shape): (5000, 12)
